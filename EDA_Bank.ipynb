# %% [markdown]
# Proyecto EDA con Python

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %% [markdown]
# # DIAGNÓSTICO INICIAL CSV

# %%
# Cargar dataset principal
df_bank = pd.read_csv("bank-additional.csv")
df_bank.head()
# Out:
#    Unnamed: 0   age        job  marital    education  default  housing  loan  \
# 0           0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0
# 1           1  57.0   services  MARRIED  high.school      NaN      0.0   0.0
# 2           2  37.0   services  MARRIED  high.school      0.0      1.0   0.0
# 3           3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0
# 4           4  56.0   services  MARRIED  high.school      0.0      0.0   1.0
#
#      contact  duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone       261         1    999         0  NONEXISTENT           1.1
# 1  telephone       149         1    999         0  NONEXISTENT           1.1
# 2  telephone       226         1    999         0  NONEXISTENT           1.1
# 3  telephone       151         1    999         0  NONEXISTENT           1.1
# 4  telephone       307         1    999         0  NONEXISTENT           1.1
#
# ...

# %%
df_bank.sample(10)
# Out:
#        Unnamed: 0   age          job  marital          education  default  \
# 14118       14215  46.0  blue-collar  MARRIED           basic.4y      0.0
# 37290       37457  28.0       admin.   SINGLE  university.degree      0.0
# 25445       25567  29.0    housemaid   SINGLE        high.school      0.0
# 18729       18826  41.0   technician  MARRIED  university.degree      0.0
# 14304       14401  38.0  blue-collar   SINGLE           basic.9y      NaN
# 7816         7913  52.0   technician  MARRIED        high.school      0.0
# 6259         6356  45.0       admin.  MARRIED           basic.9y      0.0
# 42233       34803  30.0      student   SINGLE                NaN      0.0
# 42138       31601   NaN     services  MARRIED        high.school      NaN
# 24700       24822  51.0  blue-collar  MARRIED           basic.9y      NaN
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 14118      1.0   0.0   cellular       397         3    999         0
# ...

# %%
#mostrar las últimas 5 filas del DataFrame
df_bank.tail()
# Out:
#        Unnamed: 0   age          job  marital            education  default  \
# 42995       19154   NaN       admin.  MARRIED    university.degree      0.0
# 42996       26206  34.0   technician  MARRIED  professional.course      0.0
# 42997       15046   NaN  blue-collar   SINGLE             basic.6y      0.0
# 42998       15280   NaN       admin.  MARRIED    university.degree      NaN
# 42999       27570   NaN   unemployed   SINGLE    university.degree      0.0
#
#        housing  loan   contact  duration  campaign  pdays  previous  \
# 42995      0.0   0.0  cellular       618         2    999         0
# 42996      1.0   1.0  cellular        42         7    999         0
# 42997      1.0   0.0  cellular       391         2    999         0
# 42998      0.0   0.0  cellular       674         3    999         0
# 42999      0.0   1.0  cellular       104         2    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...

# %%
df_bank.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')

# %%
df_bank.shape
# Out:
# (43000, 24)

# %%
df_bank.size
# Out:
# 1032000

# %%
df_bank.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0   age          job  marital            education  default  \
# 0               0   NaN    housemaid  MARRIED             basic.4y      0.0
# 1               1  57.0     services  MARRIED          high.school      NaN
# 2               2  37.0     services  MARRIED          high.school      0.0
# 3               3  40.0       admin.  MARRIED             basic.6y      0.0
# 4               4  56.0     services  MARRIED          high.school      0.0
# ...           ...   ...          ...      ...                  ...      ...
# 42995       19154   NaN       admin.  MARRIED    university.degree      0.0
# 42996       26206  34.0   technician  MARRIED  professional.course      0.0
# 42997       15046   NaN  blue-collar   SINGLE             basic.6y      0.0
# 42998       15280   NaN       admin.  MARRIED    university.degree      NaN
# 42999       27570   NaN   unemployed   SINGLE    university.degree      0.0
#
# ...

# %%
df_bank.dtypes
# Out:
# Unnamed: 0          int64
# age               float64
# job                object
# marital            object
# education          object
# default           float64
# housing           float64
# loan              float64
# contact            object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx     object
# cons.conf.idx      object
# euribor3m          object
# nr.employed        object
# y                  object
# date               object
# latitude          float64
# longitude         float64
# id_                object
# dtype: object

# %%
df_bank.isnull().sum()
# Out:
# Unnamed: 0           0
# age               5120
# job                345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx     471
# cons.conf.idx        0
# euribor3m         9256
# nr.employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# dtype: int64

# %%
df_bank.describe().T
# Out:
#                 count          mean           std      min          25%  \
# Unnamed: 0    43000.0  20651.099047  11868.770913    0.000  10381.75000
# age           37880.0     39.977112     10.437957   17.000     32.00000
# default       34019.0      0.000088      0.009390    0.000      0.00000
# housing       41974.0      0.535998      0.498708    0.000      0.00000
# loan          41974.0      0.155620      0.362499    0.000      0.00000
# duration      43000.0    257.739279    258.666033    0.000    102.00000
# campaign      43000.0      2.567233      2.772294    1.000      1.00000
# pdays         43000.0    962.330953    187.260394    0.000    999.00000
# previous      43000.0      0.174023      0.497366    0.000      0.00000
# emp.var.rate  43000.0      0.077128      1.573898   -3.400     -1.80000
# latitude      43000.0     36.856697      7.225948   24.396     30.61475
# longitude     43000.0    -95.939067     16.752282 -124.997   -110.49425
#
# ...

# %% [markdown]
# # DIAGNÓSTICO INICIAL EXCEL

# %%
# !pip install openpyxl
# Out:
# zsh:1: command not found: pip

# %%
# para poder leer el excel con pandas, intalamos openpyxl:
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
df_customers = pd.read_excel("customer-details.xlsx", sheet_name=None)

# %%
#Como el excel tiene tres hojas, usamos el .keys para cargar todas
df_customers.keys()
# Out:
# dict_keys(['2012', '2013', '2014'])

# %% [markdown]
# 2012

# %%
#accedemos a cada hoja, creando otro df
df_2012 = df_customers['2012']
df_2012.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  161770        1         0  2012-04-04                 29
# 1           1   85477        1         1  2012-12-30                  7
# 2           2  147233        1         1  2012-02-02                  5
# 3           3  121393        1         2  2012-12-21                 29
# 4           4   63164        1         2  2012-06-20                 20
#
#                                      ID
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
print(df_2012.info())
print(df_2012.describe())
print(df_2012.isnull().sum())
print(df_2012.shape)
print(df_2012.size)
print(df_2012.dtypes)
print(df_2012.columns)
df_2012
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20115 entries, 0 to 20114
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20115 non-null  int64
#  1   Income             20115 non-null  int64
#  2   Kidhome            20115 non-null  int64
#  3   Teenhome           20115 non-null  int64
#  4   Dt_Customer        20115 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  20115 non-null  int64
#  6   ID                 20115 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.1+ MB
# None
#          Unnamed: 0         Income       Kidhome      Teenhome  \
# count  20115.000000   20115.000000  20115.000000  20115.000000
# mean   10057.000000   93087.213224      1.004176      0.999503
# min        0.000000    5852.000000      0.000000      0.000000
# 25%     5028.500000   49110.000000      0.000000      0.000000
# ...

# %% [markdown]
# 2013

# %%
df_2013 = df_customers['2013']
df_2013.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0   82407        0         1  2013-10-07                 29
# 1           1   24877        0         0  2013-04-21                 32
# 2           2   78839        1         0  2013-11-25                 21
# 3           3  113859        1         1  2013-01-06                 12
# 4           4  147317        0         0  2013-07-10                 14
#
#                                      ID
# 0  ef81336c-e41a-46d0-8a30-5d4ac3b836be
# 1  50b224ac-84b4-42a7-aba9-3e1d1d620479
# 2  9cb15c53-b647-464a-add9-09cdae04897c
# 3  f8aaf334-949d-4943-a214-b64fe9c088b4
# 4  885fe85a-3718-4760-a32a-a57628cf7528

# %%
print(df_2013.info())
print(df_2013.describe())
print(df_2013.isnull().sum())
print(df_2013.shape)
print(df_2013.size)
print(df_2013.dtypes)
print(df_2013.columns)
df_2013
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8965 entries, 0 to 8964
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         8965 non-null   int64
#  1   Income             8965 non-null   int64
#  2   Kidhome            8965 non-null   int64
#  3   Teenhome           8965 non-null   int64
#  4   Dt_Customer        8965 non-null   datetime64[ns]
#  5   NumWebVisitsMonth  8965 non-null   int64
#  6   ID                 8965 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 490.4+ KB
# None
#         Unnamed: 0         Income      Kidhome     Teenhome  \
# count  8965.000000    8965.000000  8965.000000  8965.000000
# mean   4482.000000   92788.951255     0.991523     0.995761
# min       0.000000    5848.000000     0.000000     0.000000
# 25%    2241.000000   49866.000000     0.000000     0.000000
# ...

# %% [markdown]
# 2014

# %%
df_2014 = df_customers['2014']
df_2014.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  168812        1         1  2014-06-10                 27
# 1           1  108615        2         1  2014-04-05                 24
# 2           2  179041        0         2  2014-09-22                  4
# 3           3  116639        2         2  2014-08-16                  3
# 4           4   49537        0         1  2014-09-05                 28
#
#                                      ID
# 0  4d6c811c-0f24-4a73-b374-2ebd1f80d46e
# 1  eef0f24f-cbdb-4c67-b371-09d7bc59695e
# 2  bbfdcedd-199d-4927-94bb-5dad051ff471
# 3  e8ebb67d-4ee1-4615-b701-eefe3af607eb
# 4  f7f79ace-0024-4505-a401-f340946f0942

# %%
print(df_2014.info())
print(df_2014.describe())
print(df_2014.isnull().sum())
print(df_2014.shape)
print(df_2014.size)
print(df_2014.dtypes)
print(df_2014.columns)
df_2014
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14090 entries, 0 to 14089
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         14090 non-null  int64
#  1   Income             14090 non-null  int64
#  2   Kidhome            14090 non-null  int64
#  3   Teenhome           14090 non-null  int64
#  4   Dt_Customer        14090 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  14090 non-null  int64
#  6   ID                 14090 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 770.7+ KB
# None
#          Unnamed: 0         Income       Kidhome      Teenhome  \
# count  14090.000000   14090.000000  14090.000000  14090.000000
# mean    7044.500000   93706.470405      1.013982      0.999219
# min        0.000000    5841.000000      0.000000      0.000000
# 25%     3522.250000   50180.250000      0.000000      0.000000
# ...

# %% [markdown]
# # LIMPIEZA Y TRANSFORMACIÓN DE DATOS
